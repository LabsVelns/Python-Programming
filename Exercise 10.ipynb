# %% [markdown]
# ###Q1: Write a function to compute 5/0 and use try/except to catch the exceptions.

# %%
#Assertion method
x= 5
y = 0
assert y!=0 , "Division by Zero Error"
print(x/y)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-9c2bd9e008e3> in <cell line: 4>()
#       2 y = 0
#       3
# ----> 4 assert y!=0 , "Division by Zero Error"
#       5
#       6 print(x/y)
#
# AssertionError: Division by Zero Error

# %%
#builtin exception
try :
  x = 5/0

except:
  print("You cannot divide by zero")

finally:
  print("Code Ended")
# Out:
# You cannot divide by zero
# Code Ended

# %%
import sys
try:
  x = 5/0
except ZeroDivisionError as zx :
  print(zx)
  print(sys.exc_info())
# Out:
# division by zero
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x7f7edbdee580>)

# %%
#Raising Error
try:
  x = 5
  y = 3

  if y<=0 :
    raise ZeroDivisionError ("This is not possible")
except ZeroDivisionError as ve:
  print(ve)

else :
  print(x/y)
# Out:
# 1.6666666666666667

# %%
#Raising Error
try:
  x = 5
  y = 0

  if y<=0 :
    raise ZeroDivisionError ("This is not possible")
except ZeroDivisionError as ve:
  print(ve)

else :
  print(x/y)
# Out:
# This is not possible

# %% [markdown]
# ###Q2: Write a Python program to access the array element whose index is out of bound and handle the corresponding exception

# %%
import sys
try:
  x = [1,3,5,2]
  print(x[4])
except (ZeroDivisionError,IndexError,NameError) as zx :
  print(zx)
  print(sys.exc_info()[0])
# Out:
# list index out of range
# <class 'IndexError'>

# %% [markdown]
# ###Q 3: Write a Python Program to handle multiple errors with one except statement

# %%
import sys
try:
  z = 5/0
  x = [1,3,5,2]
  print(x[4])
  print(array)
except (ZeroDivisionError,IndexError,NameError) as zx :
  print(zx)
  print(sys.exc_info()[0])
  print("-----------------------------")
try:
  #z = 5/0
  x = [1,3,5,2]
  print(x[4])
  print(array)
except (ZeroDivisionError,IndexError,NameError) as zx :
  print(zx)
  print(sys.exc_info()[0])
  print("-----------------------------")
try:
  #z = 5/0
  x = [1,3,5,2]
  #print(x[4])
  print(array)
except (ZeroDivisionError,IndexError,NameError) as zx :
  print(zx)
  print(sys.exc_info()[0])
  print("-----------------------------")
# Out:
# division by zero
# <class 'ZeroDivisionError'>
# -----------------------------
# list index out of range
# <class 'IndexError'>
# -----------------------------
# name 'array' is not defined
# <class 'NameError'>
# -----------------------------

# %% [markdown]
# ###Q 4: Write a Python Program to depict else clause with try-except

# %%
#Raising Error
try:
  x = 5
  y = 3

  if y<=0 :
    raise ZeroDivisionError ("This is not possible")
except ZeroDivisionError as ve:
  print(ve)

else :
  print(x/y)
print("_______________________________")

#Raising Error
try:
  x = 5
  y = 0

  if y<=0 :
    raise ZeroDivisionError ("This is not possible")
except ZeroDivisionError as ve:
  print(ve)

else :
  print(x/y)
# Out:
# 1.6666666666666667
# _______________________________
# This is not possible

# %% [markdown]
# ###Q5: Write a Python Program to depict Raising Exception

# %%
#Raising Error
try:
  x = 5
  y = 0

  if y<=0 :
    raise ZeroDivisionError ("This is not possible")
except ZeroDivisionError as ve:
  print(ve)

else :
  print(x/y)
# Out:
# This is not possible

# %% [markdown]
# ###Q6: Write a python program to create user-defined exception

# %%
import sys
class Error(Exception):
  def __init__(self,s):
    self.s = s
try:
  num = int(input("Enter positive number: "))
  if num < 0:
    raise Error("Not a positive number") # User-defined message
  print(num)
except:
  print(sys.exc_info())
# Out:
# Enter positive number: -3
# (<class '__main__.Error'>, Error('Not a positive number'), <traceback object at 0x7f7ecf536f40>)

# %% [markdown]
# ###Q7: Print one message if the try block raises a NameError and another for other errors:

# %%
import sys
try:
  #z = 5/0
  x = [1,3,5,2]
  #print(x[4])
  print(array)

except NameError as na:
  print("DefinationError : ",na)
  print("-----------------------------")
except (ZeroDivisionError,IndexError) as zx :
  print(zx)
  print(sys.exc_info()[0])
  print("-----------------------------")

try:
  #z = 5/0
  x = [1,3,5,2]
  print(x[4])
  #print(array)

except NameError as na:
  print("DefinationError : ",na)
  print("-----------------------------")
except (ZeroDivisionError,IndexError) as zx :
  print(zx)
  print(sys.exc_info()[0])
  print("-----------------------------")

try:
  z = 5/0
  x = [1,3,5,2]
  #print(x[4])
  #print(array)

except NameError as na:
  print("DefinationError : ",na)
  print("-----------------------------")
except (ZeroDivisionError,IndexError) as zx :
  print(zx)
  print(sys.exc_info()[0])
  print("-----------------------------")
# Out:
# DefinationError :  name 'array' is not defined
# -----------------------------
# list index out of range
# <class 'IndexError'>
# -----------------------------
# division by zero
# <class 'ZeroDivisionError'>
# -----------------------------

# %% [markdown]
# ###Q8: Try to open and write to a file that is not writable:

# %%
f = open('/content/sample_data/README.md',mode ='r')
try:
  f.write("Hello World") # Writing to file that is not writable
  print(f.read())
except:
  print("File not found")
# Out:
# File not found

# %% [markdown]
# ###Q9: Write a python program to raise an error and stop the program if x is lower than 0.

# %%
class Error(Exception):
  pass
x = int(input("Enter number (0<) -"))
try:
  if x<0 :
    raise Error("Not Greater than 0")
  print(x)
except:
  print(sys.exc_info()[1])
# Out:
# Enter number (0<) --1
# Not Greater than 0

# %% [markdown]
# ###Q10: Write a python program to raise a TypeError if x is not an integer:

# %%
try:
  a =input("Enter a integer: ")
  if type(a) is not int:     
    raise TypeError("Invalid")
  print(a)
except TypeError as te:
  print(te)
# Out:
# Enter a integer: a
# Invalid
