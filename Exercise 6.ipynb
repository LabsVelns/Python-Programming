# %% [markdown]
# ###1. Write a program to prompt for a file name, and then read through the file line-by-line. Note:
# the file name is Erle.txt and its content is,
# Erle is the enabling technology for the
# next generation of aerial and terrestrial
# robots that will be used in cities solving
# tasks such as surveillance, environmental
# monitoring or even providing aid at catastrophes.
# ###Ensure you create the file.

# %%
x = input("Enter the file name -")
f = open(x,mode ='r')
print(f.read())
f.close()
# Out:
# Enter the file name -/content/drive/MyDrive/Colab/Module2 ex 6/Erle.txt
# Erle is the enabling technology for the next generation of aerial and terrestrial robots.
# That will be used in cities solving tasks such as
# surveillance, environmental monitoring or even providing aid at catastrophes.

# %% [markdown]
# ###2.  Write a Python program to read first n lines of a file.

# %%
x = input("Enter the file name -")
f = open(x,mode ='r')
print(f.readline())
f.close()
# Out:
# Enter the file name -/content/drive/MyDrive/Colab/Module2 ex 6/Erle.txt
# Erle is the enabling technology for the next generation of aerial and terrestrial robots.

# %% [markdown]
# ###3. Write a Python program to append text to a file and display the text.

# %%
x = input("Enter the file name -")
f = open(x,mode ='a+')
f.write("\nCDAC NOIDA")
f.seek(0)
print(f.read())
f.close()
# Out:
# Enter the file name -/content/drive/MyDrive/Colab/Module2 ex 6/Erle.txt
# Erle is the enabling technology for the next generation of aerial and terrestrial robots.
# That will be used in cities solving tasks such as
# surveillance, environmental monitoring or even providing aid at catastrophes.
# CDAC NOIDA

# %% [markdown]
# ###4. Write a Python program to read a file line by line and store it into a list.

# %%
x = input("Enter the file name -")
f = open(x,mode ='r')
y = f.readlines()
print(y)
f.close()
# Out:
# Enter the file name -/content/drive/MyDrive/Colab/Module2 ex 6/Erle.txt
# ['Erle is the enabling technology for the next generation of aerial and terrestrial robots.\n', 'That will be used in cities solving tasks such as \n', 'surveillance, environmental monitoring or even providing aid at catastrophes.\n', 'CDAC NOIDA']

# %% [markdown]
# ###5. Write a program to print each line of a file in reverse order.

# %%
x = input("Enter the file name -")
f = open(x,mode ='r')
y = f.readlines()
y.reverse()
for i in y:
  z += i
print(z)
f.close()
# Out:
# Enter the file name -/content/drive/MyDrive/Colab/Module2 ex 6/Erle2.txt
#
# .stobor lairtserret dna lairea fo noitareneg txen eht rof ygolonhcet gnilbane eht si elrEADION CADC
# .sehportsatac ta dia gnidivorp neve ro gnirotinom latnemnorivne ,ecnallievrus
#  sa hcus sksat gnivlos seitic ni desu eb lliw tahT
# .stobor lairtserret dna lairea fo noitareneg txen eht rof ygolonhcet gnilbane eht si elrECDAC NOIDAsurveillance, environmental monitoring or even providing aid at catastrophes.
# That will be used in cities solving tasks such as
# Erle is the enabling technology for the next generation of aerial and terrestrial robots.
# CDAC NOIDAsurveillance, environmental monitoring or even providing aid at catastrophes.
# That will be used in cities solving tasks such as
# Erle is the enabling technology for the next generation of aerial and terrestrial robots.
# CDAC NOIDAsurveillance, environmental monitoring or even providing aid at catastrophes.
# ...

# %% [markdown]
# ###6. Write a Python program to write a list content to a file.

# %%
x = input("Enter the file name -")
with open(x, mode = "w+") as f:
  l1 = list(input("Enter the content for list - ").split(","))
  f.writelines(l1)
  f.seek(0)
  print(f.read())
# Out:
# Enter the file name -/content/drive/MyDrive/Colab/Module2 ex 6/Erle2.txt
# Enter the content for list - Hello, Myself, Harshad
# Hello Myself Harshad

# %% [markdown]
# ###7. Write a program to compute the number of characters, words and lines in a file.

# %%
 
x=input("Enter the file name - ")

def countLines():
  f = open(x, mode = "r")
  y = f.readlines()
  f.seek(0)
  print(len(y))
  f.close()

def countChar():
  f = open(x, mode = "r")
  f.seek(0)
  print(len(f.read()))
  f.close()

def countWords():
  f = open(x, mode = "r")
  y = f.readlines()
  z = [ i.split(" ") for i in y]
  f.seek(0)
  f.close()
  l2 =[]
  for i in z :
    for j in i :
      l2.append(j)
  print(len(l2))
  f.close()
countLines()
countWords()
countChar()
# Out:
# Enter the file name - /content/drive/MyDrive/Colab/Module2 ex 6/Erle.txt
# 4
# 36
# 229
