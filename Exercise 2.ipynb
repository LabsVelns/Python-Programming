# %% [markdown]
# ###Q1: Write a Python program to sum all the items in a list.

# %%
L1 = [11,23,45,67,23]
sum(L1)
# Out:
# 169

# %% [markdown]
# ###Q2: Write a Python program to get the largest number from a list.

# %%
L1 = [13,43,65,87,123,54,322,5443,32321,11111,9865]
L1.sort()
print(L1[-1])
# Out:
# 32321

# %% [markdown]
# ###Q3: Write a Python program to get the smallest number from a list.

# %%
L1 = [13,43,65,87,123,54,322,5443,32321,11111,9865]
L1.sort()
print(L1[0])
# Out:
# 13

# %% [markdown]
# ###Q4: Write a Python program to display the first and last colors from the following list.
# color_list = [&quot;Red&quot;,&quot;Green&quot;,&quot;White&quot; ,&quot;Black&quot;]

# %%
color_list = ["Red","Green","White" ,"Black"]
print(color_list[::3])
# Out:
# ['Red', 'Black']

# %% [markdown]
# ###Q5: Write a Python program to add 'ing' at the end of a given string (length should be at least 3).
# ###If the given string is already ends with 'ing' then add 'ly' instead.

# %%
str1 = input("Enter a word : ")
if str1[-3:] == 'ing' :
  print(str1 + 'ly')
else :
  print(str1 + 'ing')
# Out:
# Enter a word : color
# coloring

# %% [markdown]
# ###Q6: The marks obtained by a student in 5 different Subjects are input through a keyboard. The Student gets a division as per the following rules.
# 1. Percentage above or equal to 60 – First Division
# 2. Percentage between 50 and 59 – Second Division
# 3. Percentage between 40 and 49 – Third Division
# 4. Percentage less than 40 – Fail

# %%
L1 = int(input("Enter the subject marks = "))
L2 = int(input("Enter the subject marks = "))
L3 = int(input("Enter the subject marks = "))
L4 = int(input("Enter the subject marks = "))
L5 = int(input("Enter the subject marks = "))
y= L1 + L2 + L3 + L4+ L5
per = (y/500)*100
print("Percentage = ",per)
if (per >= 60):
  print("Passed for First Division")
elif(per <= 59 and per >= 50):
  print("Passed for Second Division")
elif(per <= 49 and per >= 40):
  print("Passed for Third Division")
else :
  print("FAIL")
# Out:
# Enter the subject marks = 50
# Enter the subject marks = 50
# Enter the subject marks = 50
# Enter the subject marks = 50
# Enter the subject marks = 50
# Percentage =  50.0
# Passed for Second Division

# %% [markdown]
# ###Q7: write a Python program to find the largest number among the three input numbers

# %%
x1 = int(input("Enter a number - "))
x2 = int(input("Enter a number - "))
x3 = int(input("Enter a number - "))
L1 = [x1,x2,x3]
L1.sort()
print("Largest number is %d" %L1[-1])
# Out:
# Enter a number - 45
# Enter a number - 66
# Enter a number - 55
# Largest number is 66

# %% [markdown]
# ###Q8:Write a Python program to check if the input year is a leap year or not.

# %%
year = int(input("Enter the year = "))
if (year%100 != 0 or year%400 == 0):
  if (year%4 == 0):
    print("Given year is Leap year")
  else :
    print ("It's not a leap year")  
else :
  print("It's not a leap year")
# Out:
# Enter the year = 1992
# Given year is Leap year

# %% [markdown]
# ###Q9: write a Program to check if a string is palindrome or not

# %%
str1 = 'olo'
if str1 == str1[::-1]:
  print("Given string is Palindrome")
else :
  print("Given String isn't Palindrome")
# Out:
# Given string is Palindrome

# %% [markdown]
# Q10: Given a nested list. Write a python program to extend it with adding sub list [&quot;h&quot;, &quot;i&quot;, &quot;j&quot;]
# in a such a way that it will look like the following list
# Given List:
# list1 = [&quot;a&quot;, &quot;b&quot;, [&quot;c&quot;, [&quot;d&quot;, &quot;e&quot;, [&quot;f&quot;, &quot;g&quot;], &quot;k&quot;], &quot;l&quot;], &quot;m&quot;, &quot;n&quot;]
# Sub List to be added = [&quot;h&quot;, &quot;i&quot;, &quot;j&quot;]
#
# Expected output:
# [&#39;a&#39;, &#39;b&#39;, [&#39;c&#39;, [&#39;d&#39;, &#39;e&#39;, [&#39;f&#39;, &#39;g&#39;, &#39;h&#39;, &#39;i&#39;, &#39;j&#39;], &#39;k&#39;], &#39;l&#39;], &#39;m&#39;, &#39;n&#39;]

# %%
L1 =  ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
L2 = ["h", "i", "j"]
L1[2][1][2].extend(L2)
print(L1)
# Out:
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %% [markdown]
# ###Q11: Write a python program for Given a Python list, to find value 20 in the list, and if it is present, replace it with 200. Only update the first occurrence of a value
# list1 = [5, 10, 15, 20, 25, 50, 20]
# Expected output:
# list1 = [5, 10, 15, 200, 25, 50, 20]

# %%
L1 = [5, 10, 15, 20, 25, 50, 20]

L1[L1.index(20)]=200
print(L1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]
